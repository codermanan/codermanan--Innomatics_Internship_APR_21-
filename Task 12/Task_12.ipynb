# %% [markdown]
# **PUBG PLAYERS DATASET**
#
# Team Members Detail:
#
#
# *   Manan Pareek
#     mananpareek99@gmail.com
# *   Mehul Khandelwal
#     mehulkhandelwal1290@gmail.com

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("/content/data(2).csv");
df.head()
# Out:
#    Unnamed: 0              Id  ... winPoints winPlacePerc
# 0     2093518  a3e3cea9f2e314  ...    1525.0       0.0667
# 1     3701672  43e4be7ad72cc7  ...    1516.0       0.5862
# 2     2059784  9a68690e31fdff  ...       0.0       0.8105
# 3     1302036  b147e1bd448fc4  ...    1515.0       0.5556
# 4      297180  d818b4edd59612  ...       0.0       0.6429
#
# [5 rows x 30 columns]

# %%
print("No. of dimensions : ",df.ndim)
print("Shape of dataset :",df.shape)
print("No. of elements in dataset :",df.size)
print("Memory usage of each columns in bytes:\n",df.memory_usage())
# Out:
# No. of dimensions :  2
# Shape of dataset : (58877, 30)
# No. of elements in dataset : 1766310
# Memory usage of each columns in bytes:
#  Index                 128
# Unnamed: 0         471016
# Id                 471016
# groupId            471016
# matchId            471016
# assists            471016
# boosts             471016
# damageDealt        471016
# DBNOs              471016
# headshotKills      471016
# heals              471016
# killPlace          471016
# killPoints         471016
# kills              471016
# killStreaks        471016
# longestKill        471016
# matchDuration      471016
# matchType          471016
# maxPlace           471016
# numGroups          471016
# rankPoints         471016
# revives            471016
# rideDistance       471016
# roadKills          471016
# swimDistance       471016
# teamKills          471016
# vehicleDestroys    471016
# walkDistance       471016
# weaponsAcquired    471016
# winPoints          471016
# ...

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True )

# %%
df.shape
# Out:
# (58877, 29)

# %%
df.describe()
# Out:
#             assists        boosts  ...     winPoints  winPlacePerc
# count  58876.000000  58876.000000  ...  58876.000000  58876.000000
# mean       0.231453      1.110249  ...    606.487041      0.473391
# std        0.584804      1.716677  ...    739.728344      0.307158
# min        0.000000      0.000000  ...      0.000000      0.000000
# 25%        0.000000      0.000000  ...      0.000000      0.200000
# 50%        0.000000      0.000000  ...      0.000000      0.461500
# 75%        0.000000      2.000000  ...   1495.000000      0.741900
# max       12.000000     24.000000  ...   1970.000000      1.000000
#
# [8 rows x 25 columns]

# %%
df.isnull().sum()
# Out:
# Id                 0
# groupId            0
# matchId            0
# assists            1
# boosts             1
# damageDealt        1
# DBNOs              1
# headshotKills      1
# heals              1
# killPlace          1
# killPoints         1
# kills              1
# killStreaks        1
# longestKill        1
# matchDuration      1
# matchType          1
# maxPlace           1
# numGroups          1
# rankPoints         1
# revives            1
# rideDistance       1
# roadKills          1
# swimDistance       1
# teamKills          1
# vehicleDestroys    1
# walkDistance       1
# weaponsAcquired    1
# winPoints          1
# winPlacePerc       1
# dtype: int64

# %% [markdown]
# Filling missing value in winplaceperc with mean

# %%
df['winPlacePerc']=df['winPlacePerc'].fillna(df['winPlacePerc'].mean())

# %%
df1=df.select_dtypes(include=['float64', 'int64'])
df2=df.select_dtypes(include=['object'])

# %%
df1.columns
# Out:
# Index(['assists', 'boosts', 'damageDealt', 'DBNOs', 'headshotKills', 'heals',
#        'killPlace', 'killPoints', 'kills', 'killStreaks', 'longestKill',
#        'matchDuration', 'maxPlace', 'numGroups', 'rankPoints', 'revives',
#        'rideDistance', 'roadKills', 'swimDistance', 'teamKills',
#        'vehicleDestroys', 'walkDistance', 'weaponsAcquired', 'winPoints',
#        'winPlacePerc'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Id', 'groupId', 'matchId', 'matchType'], dtype='object')

# %% [markdown]
# Checking outliers for each numerical column

# %%
df1.boxplot(figsize=(30,25))

# %% [markdown]
# Univariate analysis
# Understanding the probability and frequency distribution of each numerical column

# %%
df1.hist(figsize=(20,20))
plt.show()

# %%
sns.distplot(df1['assists'])

# %%
sns.distplot(df1['boosts'])

# %%
sns.distplot(df1['damageDealt'])

# %%
sns.distplot(df1['DBNOs'])

# %%
sns.distplot(df1['headshotKills'])

# %%
sns.distplot(df1['heals'])

# %%
sns.distplot(df1['killPlace'])

# %%
sns.distplot(df1['killPoints'])

# %%
sns.distplot(df1['kills'])

# %%
sns.distplot(df1['killStreaks'])

# %%
sns.distplot(df1['longestKill'])

# %%
sns.distplot(df1['matchDuration'])

# %%
sns.distplot(df1['maxPlace'])

# %%
sns.distplot(df1['numGroups'])

# %%
sns.distplot(df1['revives'])

# %%
sns.distplot(df1['rideDistance'])

# %%
sns.distplot(df1['swimDistance'])

# %% [markdown]
# **Bivariate analysis**
#
# Discover the relationships between numerical columns

# %%
df1.corr()
# Out:
#                   assists    boosts  ...  winPoints  winPlacePerc
# assists          1.000000  0.303247  ...   0.031420      0.299816
# boosts           0.303247  1.000000  ...   0.002073      0.632635
# damageDealt      0.403455  0.525824  ...   0.023440      0.443347
# DBNOs            0.309290  0.357734  ...   0.014794      0.280954
# headshotKills    0.193427  0.337502  ...   0.007541      0.280142
# heals            0.228445  0.531717  ...  -0.007786      0.426806
# killPlace       -0.285447 -0.552557  ...  -0.005840     -0.718912
# killPoints       0.046499  0.018424  ...   0.983189      0.018925
# kills            0.312102  0.502601  ...   0.012594      0.423201
# killStreaks      0.237051  0.398502  ...   0.012640      0.376476
# longestKill      0.254962  0.414305  ...   0.000413      0.407303
# matchDuration   -0.020113  0.068638  ...  -0.083900     -0.010932
# maxPlace        -0.147879 -0.011999  ...  -0.028385      0.037462
# ...

# %%
plt.figure(figsize=(20,20))

sns.heatmap(df1.corr(),linewidths=.1,cmap="YlGnBu", annot=True)

plt.yticks(rotation=0);

# %% [markdown]
# kill point and win point are 98% correlated & win point and rankpoints are 99% correlated

# %%
plt.figure(figsize=(20,10))
sns.relplot(x='DBNOs',y='kills',hue ='matchType',data =df)
plt.show()

# %%
plt.figure(figsize=(18,10))
sns.lineplot(x='teamKills',y='kills',label='matchType',data=df)
plt.show()
